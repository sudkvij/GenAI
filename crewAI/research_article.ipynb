# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Agent, Task, Crew

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
os.environ["OPENAI_MODEL_NAME"] = 'gpt-3.5-turbo'

# %%
planner = Agent(
        role="Content Planner",
        goal = "Plan engaging and factually accurate content on {topic}",
        backstory= "You're working on planning a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic.",
        allow_delegation=False,
        verbose=True
)

# %%
writer = Agent(
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory="You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements.",
    allow_delegation=False,
    verbose=True
)

# %%
plan = Task (
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=planner
)

# %%
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output="A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs.",
    agent=writer,
)

# %%
crew = Crew(
    agents = [planner,writer],
    tasks = [plan,write],
    verbose=False
)

# %%
result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# Out:
# # Agent: Content Planner
# ## Task: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.
# 2. Identify the target audience, considering their interests and pain points.
# 3. Develop a detailed content outline including an introduction, key points, and a call to action.
# 4. Include SEO keywords and relevant data or sources.
#
#
# # Agent: Content Planner
# ## Final Answer:
# Content Plan:
# Title: Exploring Artificial Intelligence: Trends, Players, and Future Insights
#
# Outline:
# I. Introduction
#     A. Definition of Artificial Intelligence (AI)
#     B. Importance and applications of AI in various industries
#
# II. Latest Trends in Artificial Intelligence
#     A. Machine Learning advancements
#     B. Natural Language Processing developments
#     C. AI in healthcare, finance, and autonomous vehicles
#     D. Ethical considerations in AI technologies
#
# III. Key Players in the AI Industry
#     A. Technology Giants: Google, Amazon, Microsoft
#     B. AI Startups disrupting industries
#     C. Research institutions leading AI innovation
#
# IV. Noteworthy News in Artificial Intelligence
#     A. Recent breakthroughs in AI research
#     B. Impact of AI on job markets
#     C. AI regulations and policies
#
# V. Target Audience Analysis
#     A. Professionals in tech industries seeking AI insights
#     B. Business owners exploring AI integration opportunities
#     C. Students and researchers interested in AI advancements
#
# VI. SEO Keywords: Artificial Intelligence, AI trends, Machine Learning, Natural Language Processing, AI companies, AI news
#
# VII. Resources:
#     A. Forbes - Latest updates on AI trends
#     B. AI companies' websites for industry insights
#     C. TechCrunch - News on AI innovations
#     D. Stanford University AI research papers
#
# VIII. Call to Action:
#     A. Encourage readers to stay updated on AI trends by subscribing to industry newsletters
#     B. Prompt for sharing the article on social media platforms to spread AI awareness
#
# By following this comprehensive content plan, the blog article on Artificial Intelligence will provide valuable insights to the target audience, incorporating the latest trends, key players, and significant news in the AI industry.
#
#
# # Agent: Content Writer
# ## Task: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.
# 2. Incorporate SEO keywords naturally.
# 3. Sections/Subtitles are properly named in an engaging manner.
# 4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing conclusion.
# 5. Proofread for grammatical errors and alignment with the brand's voice.
#
#
#
# # Agent: Content Writer
# ## Final Answer:
# # Exploring Artificial Intelligence: Trends, Players, and Future Insights
#
# ## Introduction
# Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, notably computer systems. The significance of AI extends across diverse industries, revolutionizing operations through automation, data analysis, and problem-solving. AI finds applications in healthcare, finance, transportation, and more, enhancing efficiency and enabling innovative solutions tailored to specific needs.
#
# ## Latest Trends in Artificial Intelligence
# ### Machine Learning Advancements
# Machine Learning, a subset of AI, has witnessed remarkable progress, enabling computers to learn and improve without explicit programming. This evolution has led to the development of complex algorithms that power various AI applications, promising new possibilities in data analysis and prediction.
#
# ### Natural Language Processing Developments
# Natural Language Processing (NLP) focuses on interactions between computers and human language. Recent advancements have enhanced language understanding and generation capabilities, leading to improvements in chatbots, language translation, and sentiment analysis.
#
# ### AI in Healthcare, Finance, and Autonomous Vehicles
# AI has made significant strides in healthcare, aiding in diagnostics, personalized treatment plans, and drug discovery. In finance, AI algorithms enhance fraud detection, risk assessment, and automated trading systems. Autonomous vehicles rely on AI technologies like computer vision and sensor fusion for safe navigation and decision-making.
#
# ### Ethical Considerations in AI Technologies
# As AI becomes more integrated into daily life, ethical dilemmas arise, including data privacy, algorithm bias, and the impact on employment. Addressing these concerns is crucial to ensure responsible AI development and deployment.
#
# ## Key Players in the AI Industry
# ### Technology Giants: Google, Amazon, Microsoft
# Leading tech companies like Google, Amazon, and Microsoft invest heavily in AI research and development, driving innovation in areas such as voice recognition, image processing, and recommendation systems.
#
# ### AI Startups Disrupting Industries
# Startups play a vital role in introducing novel AI solutions across sectors, challenging traditional business models and fostering competition that spurs innovation and growth.
#
# ### Research Institutions Leading AI Innovation
# Academic institutions like Stanford University and research centers worldwide contribute significantly to AI advancements, publishing groundbreaking studies and collaborating with industry leaders to push the boundaries of AI capabilities.
#
# ## Noteworthy News in Artificial Intelligence
# ### Recent Breakthroughs in AI Research
# Exciting breakthroughs in AI research include advancements in reinforcement learning, unsupervised learning, and neural network architectures, paving the way for more sophisticated AI applications.
#
# ### Impact of AI on Job Markets
# The integration of AI technologies can lead to job displacement in certain sectors while creating new opportunities in AI-related roles requiring specialized skills and expertise. Balancing workforce needs amidst automation remains a critical challenge.
#
# ### AI Regulations and Policies
# Governments and regulatory bodies are establishing frameworks to govern AI development and deployment, addressing concerns related to transparency, accountability, and the ethical use of AI systems in society.
#
# ## Target Audience Analysis
# ### Professionals in Tech Industries Seeking AI Insights
# Tech professionals seek to deepen their understanding of AI trends and applications to leverage innovative solutions for business growth and competitive advantage.
#
# ### Business Owners Exploring AI Integration Opportunities
# Business owners are interested in integrating AI to streamline operations, enhance customer experiences, and drive strategic decision-making, positioning their companies for long-term success in a digital economy.
#
# ### Students and Researchers Interested in AI Advancements
# Academic enthusiasts and researchers in AI aim to stay informed about the latest breakthroughs, trends, and industry developments to contribute to the evolving landscape of artificial intelligence.
#
# ## Resources
# - **Forbes**: Offers the latest updates on AI trends, market analysis, and expert insights.
# - **AI Companies' Websites**: Provide valuable industry insights, product information, and case studies demonstrating AI applications.
# - **TechCrunch**: Delivers news on AI innovations, startup funding, and emerging technologies shaping the AI landscape.
# - **Stanford University AI Research Papers**: Offer scholarly articles, research papers, and resources for in-depth exploration of AI topics.
#
# ## Call to Action
# Stay informed on AI trends by subscribing to industry newsletters and publications that provide up-to-date information on AI advancements. Help spread awareness about AI by sharing this article on social media platforms, engaging with others interested in the transformative potential of artificial intelligence.
#
# In conclusion, the dynamic landscape of Artificial Intelligence continues to evolve, driven by technological advancements, industry collaborations, and regulatory developments. Understanding the latest trends, key players, and ethical considerations in AI is essential for professionals, businesses, and researchers looking to navigate the future of AI innovation effectively.
